# %%
import importlib.util
import sys
import os

# Assure-toi que le dossier des modules est bien dans le path
sys.path.append(os.path.abspath("../app/services"))

# Chargement dynamique du fichier runner_test.py
file_path = "../app/services/runner_test.py"
spec = importlib.util.spec_from_file_location("runner_test", file_path)
runner_test = importlib.util.module_from_spec(spec)
spec.loader.exec_module(runner_test)

print("✅ Module runner_test chargé avec succès !")
# Out:
# ✅ Module runner_test chargé avec succès !

# %%
params = {
    "og_tables": ["../data/original.csv"],
    "anon_tables": ["../data/anonymized.csv"],
    "ids": ["id"],
    "count_cols": [["ville"]],
    "group_cols": [["age", "sexe"]],
    "target": ["revenu"],
    "exp_features": [["age", "sexe"]],
    "group_var": ["id"],
    "og_fusion_table": ["../data/fusion_original.csv"],
    "anon_fusion_table": ["../data/fusion_anonymized.csv"],
    "fusion_columns_to_combine": [["ville", "code_postal"]],
    "viz": True
}

# %%
results = runner_test.run_reidentification_tests(params)
results
# Out:
# Colonnes dans og_merged_tables : ['id', 'age', 'sexe', 'ville', 'revenu', 'code_postal', 'age_fusion', 'sexe_fusion', 'ville_fusion', 'revenu_fusion', 'code_postal_fusion']
# Colonnes dans anon_merged_tables : ['id', 'age', 'sexe', 'ville', 'revenu', 'code_postal', 'age_fusion', 'sexe_fusion', 'ville_fusion', 'revenu_fusion', 'code_postal_fusion']
# c:\Python312\Lib\site-packages\sklearn\metrics\_classification.py:1565: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, f"{metric.capitalize()} is", len(result))
# c:\Python312\Lib\site-packages\sklearn\metrics\_classification.py:1565: UndefinedMetricWarning: Recall is ill-defined and being set to 0.0 in labels with no true samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, f"{metric.capitalize()} is", len(result))
# ...
